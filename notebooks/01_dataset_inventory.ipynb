# %% [markdown]
# # Dataset inventory and label mapping
#
# First-buildout notebook scaffold from SPEC.md.

# %%
RUN_ID = 'first-buildout'
ARTIFACT_ROOT = 'artifacts'
print('RUN_ID:', RUN_ID)

# %%
from pathlib import Path
import json

report_dir = Path('artifacts/reports')
report_dir.mkdir(parents=True, exist_ok=True)

dataset_inventory = {
  'datasets': [
    {'name': 'FC24 Minimap Dataset', 'task': 'minimap object detection'},
    {'name': 'FIFA Minimap Dataset', 'task': 'minimap crop detection'},
    {'name': 'Soccer Field Keypoints Detection', 'task': 'pitch keypoints'},
    {'name': 'Football Field Keypoints Dataset', 'task': 'pitch keypoints'},
    {'name': 'FC26 Roboflow Dataset', 'task': 'fc26 hud/object detection'}
  ]
}

out = report_dir / 'dataset_inventory.json'
out.write_text(json.dumps(dataset_inventory, indent=2))
print(f'Wrote {out}')
