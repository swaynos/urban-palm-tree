# %% [markdown]
# # Run teacher models over local screenshots
#
# First-buildout notebook scaffold from SPEC.md.

# %%
RUN_ID = 'first-buildout'
ARTIFACT_ROOT = 'artifacts'
print('RUN_ID:', RUN_ID)
